# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Functions

# %%
#This function considers outliers as values that are greater than twice the 99th percentile value 
#and values that are less than half of the 1st percentile value.
def outliers(df):
    descriptive_stats = df.describe(percentiles=[0.01, 0.99])
    higher_99 = []
    lower_01 = []
    
    # Identificar columnas con valores mayores al percentil 99 o menores al percentil 01
    for col in df.columns:
        max_val = descriptive_stats.loc['max', col]
        percentile_99 = descriptive_stats.loc['99%', col]
        min_val = descriptive_stats.loc['min', col]
        percentile_01 = descriptive_stats.loc['1%', col]
    
        if max_val > 2 * percentile_99:
            higher_99.append(col)
    
        if min_val < percentile_01 / 2:
            lower_01.append(col)
    
    print("Variables cuyo máximo es mayor al doble del percentil 99:", higher_99)
    print("Variables cuyo mínimo es menor a la mitad del percentil 01:", lower_01)
    
    # Filtrar filas con valores atípicos
    for col in higher_99:
        threshold = descriptive_stats.loc['99%', col]
        df = df[df[col] <= threshold]
    
    for col in lower_01:
        threshold = descriptive_stats.loc['1%', col]
        df = df[df[col] >= threshold]
    
    return df

# %% [markdown]
# # Data

# %%
df = pd.read_csv('DailyDelhiClimateTrain.csv')

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %% [markdown]
# # Feature Engineering

# %%
df.dtypes
# Out:
# date             object
# meantemp        float64
# humidity        float64
# wind_speed      float64
# meanpressure    float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df['week'] = df['date'].dt.isocalendar().week #week of the year

# %%
df.sample(5)
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure  month  year  \
# 194  2013-07-14  30.750000  71.625000    4.812500      997.3750      7  2013
# 999  2015-09-27  28.714286  58.142857    2.914286     1007.0000      9  2015
# 974  2015-09-02  31.875000  45.625000   12.737500     1001.7500      9  2015
# 1305 2016-07-29  27.375000  92.437500    2.431250     1000.9375      7  2016
# 792  2015-03-04  16.750000  69.250000    6.712500     1014.0000      3  2015
#
#       week
# 194     28
# 999     39
# 974     36
# 1305    30
# 792     10

# %%
grouped = df.groupby(['week', 'year']).agg({
    'meantemp': ['max', 'min', 'mean'],
    'humidity': ['max', 'min', 'mean'],
    'wind_speed': ['max', 'min', 'mean'],
    'meanpressure': ['max', 'min', 'mean'],
    'month': ['median']
})

grouped.columns = ['_'.join(col).strip() for col in grouped.columns.values]

grouped = grouped.reset_index()

# %%
df = grouped.sort_values(by=['year', 'week'])

# %%
df.head(7)
# Out:
#     week  year  meantemp_max  meantemp_min  meantemp_mean  humidity_max  \
# 0      1  2013     14.500000      6.000000       9.138542     92.000000
# 4      2  2013     15.833333      7.000000      12.343537     78.600000
# 8      3  2013     16.500000     11.285714      13.642857     92.166667
# 12     4  2013     14.000000      9.500000      12.329592     79.666667
# 16     5  2013     18.000000     14.125000      15.736905     77.571429
# 20     6  2013     17.428571     14.000000      15.856973     92.375000
# 24     7  2013     19.166667     13.666667      16.012755     92.714286
#
#     humidity_min  humidity_mean  wind_speed_max  wind_speed_min  \
# 0      71.333333      84.167708        6.475000        0.000000
# 4      51.250000      65.145238       13.228571        4.633333
# 8      71.857143      81.663265        8.950000        0.000000
# 12     60.166667      67.748299        6.800000        2.220000
# 16     56.000000      67.667347        3.700000        1.057143
# 20     59.400000      71.515476       11.114286        3.475000
# 24     63.833333      74.693878       10.183333        0.000000
#
#     wind_speed_mean  meanpressure_max  meanpressure_min  meanpressure_mean  \
# 0          3.170521       1020.500000       1015.666667        1017.803125
# 4          8.825170       1020.000000       1013.333333        1016.632653
# 8          4.242857       1021.666667       1014.500000        1017.139456
# 12         4.770544       1021.800000       1018.142857        1020.337075
# 16         2.337194       1018.400000       1015.285714        1017.020578
# 20         8.885986       1018.666667       1014.571429        1017.048299
# 24         5.975680       1017.500000       1008.000000        1013.785714
#
#     month_median
# 0            1.0
# 4            1.0
# 8            1.0
# 12           1.0
# 16           1.0
# 20           2.0
# 24           2.0

# %%
df.columns
# Out:
# Index(['week', 'year', 'meantemp_max', 'meantemp_min', 'meantemp_mean',
#        'humidity_max', 'humidity_min', 'humidity_mean', 'wind_speed_max',
#        'wind_speed_min', 'wind_speed_mean', 'meanpressure_max',
#        'meanpressure_min', 'meanpressure_mean', 'month_median'],
#       dtype='object')

# %%
cols = ['week', 'month_median', 'meantemp_max', 'meantemp_min', 'meantemp_mean',
       'humidity_max', 'humidity_min', 'humidity_mean', 'wind_speed_max',
       'wind_speed_min', 'wind_speed_mean', 'meanpressure_max',
       'meanpressure_min', 'meanpressure_mean']

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missings

# %%
df.isna().sum()
# Out:
# week                 0
# year                 0
# meantemp_max         0
# meantemp_min         0
# meantemp_mean        0
# humidity_max         0
# humidity_min         0
# humidity_mean        0
# wind_speed_max       0
# wind_speed_min       0
# wind_speed_mean      0
# meanpressure_max     0
# meanpressure_min     0
# meanpressure_mean    0
# month_median         0
# dtype: int64

# %% [markdown]
# ## Outliers

# %%
df[cols].describe(percentiles=[0.01, 0.02, 0.05, 0.50, 0.95, 0.98, 0.99])
# Out:
#             week  month_median  meantemp_max  meantemp_min  meantemp_mean  \
# count      211.0    211.000000    211.000000    211.000000     211.000000
# mean   26.872038      6.450237     27.355832     23.361866      25.374880
# std    15.256153      3.497092      7.370552      7.110357       7.273393
# min          1.0      1.000000     10.000000      6.000000       9.138542
# 1%           1.0      1.000000     12.912500      9.050000      10.119643
# 2%           2.0      1.000000     13.400000      9.525000      12.172279
# 5%           3.0      1.000000     14.562500     11.218750      12.516879
# 50%         27.0      6.000000     29.800000     25.250000      28.048980
# 95%         50.5     12.000000     37.334559     31.812500      34.689498
# 98%         52.0     12.000000     38.000000     32.725000      35.263761
# 99%         52.0     12.000000     38.265455     33.831250      36.180357
# max         53.0     12.000000     38.714286     36.133333      37.370408
#
#        humidity_max  humidity_min  humidity_mean  wind_speed_max  \
# count    211.000000    211.000000     211.000000      211.000000
# mean      71.427801     51.699950      61.012768       12.123941
# std       16.074901     15.491013      15.284553        5.793128
# min       27.428571     13.428571      22.816497        0.000000
# 1%        32.160000     18.520000      25.773278        3.261250
# 2%        34.740000     19.700000      27.143537        3.520000
# 5%        39.758929     22.625000      31.224405        5.100000
# 50%       72.875000     54.074074      62.847518       11.550000
# 95%       92.732143     72.205357      81.685247       21.065625
# 98%       95.700000     73.775000      85.940179       27.687500
# 99%       96.833929     82.833333      90.563010       33.061071
# max      100.000000    100.000000     100.000000       42.220000
#
#        wind_speed_min  wind_speed_mean  meanpressure_max  meanpressure_min  \
# count      211.000000       211.000000        211.000000        211.000000
# mean         2.826929         6.759206       1045.328198        991.102541
# std          2.088073         2.839961        460.130112        111.283350
# min          0.000000         0.000000        996.375000         -3.041667
# 1%           0.000000         1.301811        997.631250        342.783750
# 2%           0.000000         1.790867        998.164286        939.715833
# 5%           0.000000         2.201786        999.452381        994.250000
# 50%          2.550000         6.819643       1010.857143       1006.375000
# 95%          6.718750        11.416197       1021.312500       1017.062500
# 98%          7.595000        12.473163       1022.100000       1018.428571
# 99%          8.452143        12.859109       1317.566667       1018.837500
# max          9.386667        13.546488       7679.333333       1019.125000
#
#        meanpressure_mean
# count         211.000000
# mean         1011.174944
# std            68.327648
# min           856.704401
# 1%            905.769975
# 2%            991.278486
# 5%            996.569345
# 50%          1009.073955
# 95%          1019.196429
# 98%          1020.316088
# 99%          1051.592735
# max          1962.011139

# %%
clean_df = outliers(df[cols])
df = df.loc[clean_df.index]
# Out:
# Variables cuyo máximo es mayor al doble del percentil 99: ['meanpressure_max']
# Variables cuyo mínimo es menor a la mitad del percentil 01: ['wind_speed_max', 'wind_speed_mean', 'meanpressure_min']

# %% [markdown]
# # EDA

# %%
sns.pairplot(df[cols])
# Out:
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shumi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.corr()
# Out:
#                        week      year  meantemp_max  meantemp_min  \
# week               1.000000  0.002560      0.095230      0.160044
# year               0.002560  1.000000      0.072761      0.087409
# meantemp_max       0.095230  0.072761      1.000000      0.961836
# meantemp_min       0.160044  0.087409      0.961836      1.000000
# meantemp_mean      0.127092  0.082891      0.990331      0.986430
# humidity_max       0.029445 -0.101481     -0.522731     -0.572793
# humidity_min       0.122550 -0.049146     -0.607341     -0.561109
# humidity_mean      0.079937 -0.077900     -0.608461     -0.601744
# wind_speed_max    -0.105847 -0.054558      0.267300      0.258598
# wind_speed_min    -0.216692  0.083162      0.555129      0.524817
# wind_speed_mean   -0.241313  0.022936      0.526414      0.487794
# meanpressure_max  -0.111193  0.046138     -0.901077     -0.878331
# meanpressure_min  -0.043420 -0.100700     -0.318003     -0.293898
# meanpressure_mean -0.086685 -0.009071     -0.815834     -0.783956
# month_median       0.969115 -0.011614      0.132498      0.188226
#
#                    meantemp_mean  humidity_max  humidity_min  humidity_mean  \
# week                    0.127092      0.029445      0.122550       0.079937
# year                    0.082891     -0.101481     -0.049146      -0.077900
# meantemp_max            0.990331     -0.522731     -0.607341      -0.608461
# meantemp_min            0.986430     -0.572793     -0.561109      -0.601744
# meantemp_mean           1.000000     -0.544008     -0.589664      -0.609844
# humidity_max           -0.544008      1.000000      0.827206       0.933677
# humidity_min           -0.589664      0.827206      1.000000       0.959722
# humidity_mean          -0.609844      0.933677      0.959722       1.000000
# wind_speed_max          0.263936     -0.209591     -0.311204      -0.291357
# wind_speed_min          0.542723     -0.463517     -0.537015      -0.541706
# wind_speed_mean         0.512690     -0.404956     -0.551718      -0.534345
# meanpressure_max       -0.901737      0.273811      0.375276       0.360950
# meanpressure_min       -0.306709      0.005089      0.072155       0.042734
# meanpressure_mean      -0.808937      0.215528      0.325632       0.300273
# month_median            0.160031      0.020209      0.095217       0.060835
#
#                    wind_speed_max  wind_speed_min  wind_speed_mean  \
# week                    -0.105847       -0.216692        -0.241313
# year                    -0.054558        0.083162         0.022936
# meantemp_max             0.267300        0.555129         0.526414
# meantemp_min             0.258598        0.524817         0.487794
# meantemp_mean            0.263936        0.542723         0.512690
# humidity_max            -0.209591       -0.463517        -0.404956
# humidity_min            -0.311204       -0.537015        -0.551718
# humidity_mean           -0.291357       -0.541706        -0.534345
# wind_speed_max           1.000000        0.322000         0.743243
# wind_speed_min           0.322000        1.000000         0.747876
# wind_speed_mean          0.743243        0.747876         1.000000
# meanpressure_max        -0.237383       -0.477439        -0.475284
# meanpressure_min        -0.057079       -0.166466        -0.161881
# meanpressure_mean       -0.203492       -0.436121        -0.434782
# month_median            -0.090576       -0.195635        -0.216385
#
#                    meanpressure_max  meanpressure_min  meanpressure_mean  \
# week                      -0.111193         -0.043420          -0.086685
# year                       0.046138         -0.100700          -0.009071
# meantemp_max              -0.901077         -0.318003          -0.815834
# meantemp_min              -0.878331         -0.293898          -0.783956
# meantemp_mean             -0.901737         -0.306709          -0.808937
# humidity_max               0.273811          0.005089           0.215528
# humidity_min               0.375276          0.072155           0.325632
# humidity_mean              0.360950          0.042734           0.300273
# wind_speed_max            -0.237383         -0.057079          -0.203492
# wind_speed_min            -0.477439         -0.166466          -0.436121
# wind_speed_mean           -0.475284         -0.161881          -0.434782
# meanpressure_max           1.000000          0.351651           0.893022
# meanpressure_min           0.351651          1.000000           0.727523
# meanpressure_mean          0.893022          0.727523           1.000000
# month_median              -0.141071         -0.060095          -0.118984
#
#                    month_median
# week                   0.969115
# year                  -0.011614
# meantemp_max           0.132498
# meantemp_min           0.188226
# meantemp_mean          0.160031
# humidity_max           0.020209
# humidity_min           0.095217
# humidity_mean          0.060835
# wind_speed_max        -0.090576
# wind_speed_min        -0.195635
# wind_speed_mean       -0.216385
# meanpressure_max      -0.141071
# meanpressure_min      -0.060095
# meanpressure_mean     -0.118984
# month_median           1.000000

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 12))
df.set_index('date')['humidity'].plot(ax=ax[0], title='Humidity over time')
df.set_index('date')['wind_speed'].plot(ax=ax[1], title='Wind speed over time')
df.set_index('date')['meanpressure'].plot(ax=ax[2], title='Average pressure over time')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='month', y='meantemp', data=df)
plt.title('Distribution of Average Temperature by Month')
plt.xlabel('Month')
plt.ylabel('Medium temperature')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='week', y='meantemp', data=df)
plt.title('Distribution of Average Temperature by Week')
plt.xlabel('Week')
plt.ylabel('Medium temperature')
plt.show()

# %%
df = pd.get_dummies(df, columns=['month', 'week'], drop_first=True, dtype=int)

# %% [markdown]
# # Model

# %%
df['y'] = df['meantemp'].shift(1)
df.dropna(inplace=True)

# %%
X = df.drop(columns=['date', 'meantemp','y'])
y = df['y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=50, batch_size=10, validation_split=0.2)
loss = model.evaluate(X_test, y_test)
print(f"Mean Squared Error: {loss}")
# Out:
# Epoch 1/50
# 80/80 [==============================] - 0s 2ms/step - loss: 479.2777 - val_loss: 177.5563
# Epoch 2/50
# 80/80 [==============================] - 0s 677us/step - loss: 49.7740 - val_loss: 8.8072
# Epoch 3/50
# 80/80 [==============================] - 0s 671us/step - loss: 6.9431 - val_loss: 4.9988
# Epoch 4/50
# 80/80 [==============================] - 0s 677us/step - loss: 5.0874 - val_loss: 4.6650
# Epoch 5/50
# 80/80 [==============================] - 0s 633us/step - loss: 4.7635 - val_loss: 4.5617
# Epoch 6/50
# 80/80 [==============================] - 0s 614us/step - loss: 4.6515 - val_loss: 4.4634
# Epoch 7/50
# 80/80 [==============================] - 0s 620us/step - loss: 4.5811 - val_loss: 4.4890
# Epoch 8/50
# 80/80 [==============================] - 0s 623us/step - loss: 4.4921 - val_loss: 4.3534
# Epoch 9/50
# 80/80 [==============================] - 0s 671us/step - loss: 4.4375 - val_loss: 4.2941
# Epoch 10/50
# 80/80 [==============================] - 0s 665us/step - loss: 4.4283 - val_loss: 4.3026
# Epoch 11/50
# 80/80 [==============================] - 0s 658us/step - loss: 4.4010 - val_loss: 4.1703
# Epoch 12/50
# 80/80 [==============================] - 0s 684us/step - loss: 4.3369 - val_loss: 4.4886
# Epoch 13/50
# 80/80 [==============================] - 0s 634us/step - loss: 4.3220 - val_loss: 4.3706
# Epoch 14/50
# 80/80 [==============================] - 0s 646us/step - loss: 4.2949 - val_loss: 4.4342
# Epoch 15/50
# 80/80 [==============================] - 0s 639us/step - loss: 4.2334 - val_loss: 4.3985
# Epoch 16/50
# 80/80 [==============================] - 0s 671us/step - loss: 4.2349 - val_loss: 4.3766
# Epoch 17/50
# 80/80 [==============================] - 0s 690us/step - loss: 4.1628 - val_loss: 4.2368
# Epoch 18/50
# 80/80 [==============================] - 0s 684us/step - loss: 4.2250 - val_loss: 4.4495
# Epoch 19/50
# 80/80 [==============================] - 0s 659us/step - loss: 4.1543 - val_loss: 4.3198
# Epoch 20/50
# 80/80 [==============================] - 0s 646us/step - loss: 4.1346 - val_loss: 4.4441
# Epoch 21/50
# 80/80 [==============================] - 0s 621us/step - loss: 4.1803 - val_loss: 4.3444
# Epoch 22/50
# 80/80 [==============================] - 0s 646us/step - loss: 4.2224 - val_loss: 4.4411
# Epoch 23/50
# 80/80 [==============================] - 0s 672us/step - loss: 4.0786 - val_loss: 4.4675
# Epoch 24/50
# 80/80 [==============================] - 0s 684us/step - loss: 4.1742 - val_loss: 4.4664
# Epoch 25/50
# 80/80 [==============================] - 0s 709us/step - loss: 4.1226 - val_loss: 4.4862
# Epoch 26/50
# 80/80 [==============================] - 0s 675us/step - loss: 4.0976 - val_loss: 4.4545
# Epoch 27/50
# 80/80 [==============================] - 0s 671us/step - loss: 4.0263 - val_loss: 4.4791
# Epoch 28/50
# 80/80 [==============================] - 0s 677us/step - loss: 4.0727 - val_loss: 4.5240
# Epoch 29/50
# 80/80 [==============================] - 0s 671us/step - loss: 4.1591 - val_loss: 4.5567
# Epoch 30/50
# 80/80 [==============================] - 0s 672us/step - loss: 4.0540 - val_loss: 4.4045
# Epoch 31/50
# 80/80 [==============================] - 0s 684us/step - loss: 3.9187 - val_loss: 4.3900
# Epoch 32/50
# 80/80 [==============================] - 0s 687us/step - loss: 4.0232 - val_loss: 4.4033
# Epoch 33/50
# 80/80 [==============================] - 0s 677us/step - loss: 3.9462 - val_loss: 4.6950
# Epoch 34/50
# 80/80 [==============================] - 0s 658us/step - loss: 3.9890 - val_loss: 4.6373
# Epoch 35/50
# 80/80 [==============================] - 0s 627us/step - loss: 4.0273 - val_loss: 4.8213
# Epoch 36/50
# 80/80 [==============================] - 0s 633us/step - loss: 3.9905 - val_loss: 4.6951
# Epoch 37/50
# 80/80 [==============================] - 0s 646us/step - loss: 4.1145 - val_loss: 4.6741
# Epoch 38/50
# 80/80 [==============================] - 0s 658us/step - loss: 4.0483 - val_loss: 4.7461
# Epoch 39/50
# 80/80 [==============================] - 0s 671us/step - loss: 3.9425 - val_loss: 4.4529
# Epoch 40/50
# 80/80 [==============================] - 0s 684us/step - loss: 3.8811 - val_loss: 4.3496
# Epoch 41/50
# 80/80 [==============================] - 0s 723us/step - loss: 3.8890 - val_loss: 4.7165
# Epoch 42/50
# 80/80 [==============================] - 0s 658us/step - loss: 3.9008 - val_loss: 4.7660
# Epoch 43/50
# 80/80 [==============================] - 0s 621us/step - loss: 3.9112 - val_loss: 4.6899
# Epoch 44/50
# 80/80 [==============================] - 0s 620us/step - loss: 3.8686 - val_loss: 4.6510
# Epoch 45/50
# 80/80 [==============================] - 0s 621us/step - loss: 3.9564 - val_loss: 4.7646
# Epoch 46/50
# 80/80 [==============================] - 0s 646us/step - loss: 3.8301 - val_loss: 4.8111
# Epoch 47/50
# 80/80 [==============================] - 0s 677us/step - loss: 3.7742 - val_loss: 4.7020
# Epoch 48/50
# 80/80 [==============================] - 0s 677us/step - loss: 3.8189 - val_loss: 4.7767
# Epoch 49/50
# 80/80 [==============================] - 0s 658us/step - loss: 3.7271 - val_loss: 4.8806
# Epoch 50/50
# 80/80 [==============================] - 0s 665us/step - loss: 3.7793 - val_loss: 4.4637
# 14/14 [==============================] - 0s 462us/step - loss: 4.5774
# Mean Squared Error: 4.577378749847412

# %%
y_pred = model.predict(X_test)
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred.flatten()})
print(results.head())
# Out:
# 14/14 [==============================] - 0s 384us/step
#          Actual  Predicted
# 54    17.428571  17.928324
# 493   31.375000  33.007927
# 835   27.625000  25.369291
# 1298  34.133333  32.428764
# 303   22.857143  24.103662

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.show()

# %%
errors = y_test - y_pred.flatten()
plt.figure(figsize=(10, 6))
plt.hist(errors, bins=20, alpha=0.7, color='blue')
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.title('Distribution of Prediction Errors')
plt.show()
